# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Question1.csv')

# %%
df
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N

# %%
# information from the dataset
print("N.o of Rows and Columns:", df.shape)
print("\n", df.head())
print("\n cols:", df.columns)
print("\n", df.describe())
print(df[['Height', 'Age']])
# Out:
# N.o of Rows and Columns: (10, 5)
#
#     Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
#
#  cols: Index(['Height', 'Weight', 'Age', 'Grip strength', 'Frailty'], dtype='object')
#
#            Height      Weight        Age  Grip strength
# count  10.000000   10.000000  10.000000      10.000000
# mean   68.600000  131.900000  32.500000      26.000000
# std     1.670662   14.231811  12.860361       4.521553
# min    65.800000  112.000000  17.000000      19.000000
# 25%    67.825000  120.750000  22.250000      22.500000
# 50%    68.450000  136.000000  29.500000      27.000000
# 75%    69.700000  141.750000  43.500000      29.750000
# max    71.500000  153.000000  51.000000      31.000000
#    Height  Age
# 0    65.8   30
# 1    71.5   19
# 2    69.4   45
# 3    68.2   22
# 4    67.8   29
# 5    68.7   50
# 6    69.8   51
# 7    70.1   23
# 8    67.9   17
# 9    66.8   39

# %%
plt.figure(figsize=(6, 6))
print("Column Names:", df.columns)
# Out:
# Column Names: Index(['Height', 'Weight', 'Age', 'Grip strength', 'Frailty'], dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
# Data analysis and visualization
plt.figure(figsize=(6, 6))
sns.scatterplot(x=df['age'], y=df['grip strength'], data=df, hue='weight')
plt.xlabel('Age (years)')
plt.ylabel('Grip Strength (lb)')
plt.title('Age vs. Grip Strength')
plt.grid(True)
plt.show()
